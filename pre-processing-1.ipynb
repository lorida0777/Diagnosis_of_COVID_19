# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('dataset.xlsx')

# %%
pd.set_option('display.max_column', 111)
pd.set_option('display.max_row', 111)

# %%
data.head()
# Out:
#         Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %% [markdown]
# # Pre-processint

# %%
df = data.copy()

# %% [markdown]
# ### Création des sous-ensembles (quit au EDA)

# %%
missing_rate = df.isna().sum()/df.shape[0]

# %%
# missing_rate

# %%
blood_colums = list(df.columns[(missing_rate < 0.9) & (missing_rate > 0.88)])

# %%
viral_colums = list(df.columns[(missing_rate < 0.80) & (missing_rate > 0.75)])

# %%
key_colums =['Patient age quantile', 'SARS-Cov-2 exam result']

# %%
df = df[key_colums + blood_colums + viral_colums]

# %%
df.head()
# Out:
#    Patient age quantile SARS-Cov-2 exam result  Hematocrit  Hemoglobin  \
# 0                    13               negative         NaN         NaN
# 1                    17               negative    0.236515    -0.02234
# 2                     8               negative         NaN         NaN
# 3                     5               negative         NaN         NaN
# 4                    15               negative         NaN         NaN
#
#    Platelets  Mean platelet volume   Red blood Cells  Lymphocytes  \
# 0        NaN                    NaN              NaN          NaN
# 1  -0.517413               0.010677         0.102004     0.318366
# 2        NaN                    NaN              NaN          NaN
# 3        NaN                    NaN              NaN          NaN
# 4        NaN                    NaN              NaN          NaN
#
#    Mean corpuscular hemoglobin concentration (MCHC)  Leukocytes  Basophils  \
# ...

# %%
df.shape
# Out:
# (5644, 16)

# %% [markdown]
# # TrainTest - Nettoyage - Encodage

# %% [markdown]
# ### TrainTest

# %%
from sklearn.model_selection import train_test_split

# %%
trainset, testset = train_test_split(df, test_size=0.2, random_state=0)

# %%
trainset['SARS-Cov-2 exam result'].value_counts()
# Out:
# SARS-Cov-2 exam result
# negative    4068
# positive     447
# Name: count, dtype: int64

# %%
testset['SARS-Cov-2 exam result'].value_counts()
# Out:
# SARS-Cov-2 exam result
# negative    1018
# positive     111
# Name: count, dtype: int64

# %% [markdown]
# ### Encodage

# %%
def ecodage(df):
    code = {
    'positive':1,
    'negative':0, 
    'detected':1, 
    'not_detected':0
       }
    for col in df.select_dtypes('object'):
        df[col] = df[col].map(code)

    return df

# %%
def imputation (df):
    df = df.dropna(axis=0)
    return df

# %%
def preprocessing(df):
    df = ecodage(df)
    df = imputation(df)

    X = df.drop('SARS-Cov-2 exam result', axis = 1)
    y = df['SARS-Cov-2 exam result']

    print(y.value_counts())

    return X, y

# %%
X_train, y_train = preprocessing(trainset)
# Out:
# SARS-Cov-2 exam result
# 0    258
# 1     38
# Name: count, dtype: int64

# %%
X_test, y_test = preprocessing(testset)
# Out:
# SARS-Cov-2 exam result
# 0    54
# 1    12
# Name: count, dtype: int64

# %% [markdown]
# ### Modelisation

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(random_state=0)

# %% [markdown]
# ### Procédure d'évaluation

# %%
from sklearn.metrics import f1_score, confusion_matrix, classification_report

# %%
from sklearn.model_selection import learning_curve

# %%
def evaluation(model):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))

    N, train_score, val_score = learning_curve(model, X_train, y_train, cv=4,scoring='f1',  train_sizes=np.linspace(0.1,1,10))
    plt.figure(figsize=(12,8))
    plt.plot(N,train_score.mean(axis=1),label = 'train score')
    plt.plot(N,val_score.mean(axis=1),label = 'validation score')
    plt.legend()

# %%
evaluation(model)
# Out:
# [[54  0]
#  [11  1]]
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        54
#            1       1.00      0.08      0.15        12
#
#     accuracy                           0.83        66
#    macro avg       0.92      0.54      0.53        66
# weighted avg       0.86      0.83      0.77        66

# %%
pd.DataFrame(model.feature_importances_, index=X_train.columns)
# Out:
#                                                          0
# Patient age quantile                              0.067741
# Hematocrit                                        0.090698
# Hemoglobin                                        0.000000
# Platelets                                         0.090975
# Mean platelet volume                              0.062138
# Red blood Cells                                   0.030598
# Lymphocytes                                       0.032673
# Mean corpuscular hemoglobin concentration (MCHC)  0.072541
# Leukocytes                                        0.287215
# Basophils                                         0.011836
# Mean corpuscular hemoglobin (MCH)                 0.112243
# Eosinophils                                       0.058342
# Mean corpuscular volume (MCV)                     0.014795
# Monocytes                                         0.040557
# Red blood cell distribution width (RDW)           0.027648

# %%
pd.DataFrame(model.feature_importances_, index=X_train.columns).plot.bar(figsize=(12,8))
# Out:
# <Axes: >
